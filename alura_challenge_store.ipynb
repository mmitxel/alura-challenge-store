# %% [markdown]
# <a href="https://colab.research.google.com/github/mmitxel/alura-challenge-store/blob/main/alura_challenge_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda1 = sum(tienda1['Precio'])
ingreso_tienda1
# Out:
# 1150880400.0

# %%
ingreso_tienda2 = sum(tienda2['Precio'])
ingreso_tienda3 = sum(tienda3['Precio'])
ingreso_tienda4 = sum(tienda4['Precio'])

# %% [markdown]
# # 2. Ventas por categoría

# %%
# ventas_tienda1 = tienda1['Categoría del Producto'].value_counts()
# ventas_tienda1 = tienda1.groupby('Categoría del Producto')['Categoría del Producto'].count()
ventas_tienda1 = tienda1.groupby('Categoría del Producto').size().sort_values(ascending=False)
ventas_tienda1
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# dtype: int64

# %%
ventas_tienda2 = tienda2.groupby('Categoría del Producto').size().sort_values(ascending=False)
ventas_tienda3 = tienda3.groupby('Categoría del Producto').size().sort_values(ascending=False)
ventas_tienda4 = tienda4.groupby('Categoría del Producto').size().sort_values(ascending=False)

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio_tienda1 = tienda1['Calificación'].mean()
promedio_tienda1
# Out:
# np.float64(3.976685036032217)

# %%
promedio_tienda2 = tienda2['Calificación'].mean()
promedio_tienda3 = tienda3['Calificación'].mean()
promedio_tienda4 = tienda4['Calificación'].mean()
# Out:
# np.float64(4.037303942348453)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
mas_vendidos_tienda1 = tienda1.groupby('Producto').size().sort_values(ascending=False)
mas_vendidos_tienda1
# Out:
# Producto
# Armario                        60
# TV LED UHD 4K                  60
# Microondas                     60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Impresora                      54
# Vaso térmico                   54
# Refrigerador                   54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Guitarra eléctrica             47
# Lavadora de ropa               47
# Silla de oficina               46
# Sofá reclinable                46
# Guitarra acústica              46
# Estufa                         45
# Mesa de centro                 44
# Kit de bancas                  44
# ...

# %%
mas_vendidos_tienda2 = tienda2.groupby('Producto').size().sort_values(ascending=False)
mas_vendidos_tienda3 = tienda3.groupby('Producto').size().sort_values(ascending=False)
mas_vendidos_tienda4 = tienda4.groupby('Producto').size().sort_values(ascending=False)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio_tienda1 = tienda1['Costo de envío'].mean()
envio_promedio_tienda1
# Out:
# np.float64(26018.60958033065)

# %%
envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

# %% [markdown]
# # Gráficos

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %% [markdown]
# ## Organización de los datos para graficarlos

# %%
# Organización de los datos para graficarlos
nombres = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
tiendas = {
    'Tienda 1': tienda1,
    'Tienda 2': tienda2,
    'Tienda 3': tienda3,
    'Tienda 4': tienda4
}

resultados = pd.DataFrame({
    'Facturación': [t['Precio'].sum() for t in tiendas.values()],
    'Calificación': [t['Calificación'].mean() for t in tiendas.values()],
    'Costo de envío': [t['Costo de envío'].mean() for t in tiendas.values()],
    'Categorías de Productos': [t.groupby('Categoría del Producto').size() for t in tiendas.values()]
}, index=tiendas.keys())

# %% [markdown]
# ## Comparativa de facturación en las cuatro tiendas

# %%
# Gráfica
ventas = resultados['Facturación'].plot(kind='bar', ylabel='Facturación ($)',
                                        figsize=(8,6), legend=False,  color='steelblue')

# Formato de números en millones
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x*1e-6:.1f}M'))

# Números en las barras
ventas.bar_label(
    ventas.containers[0],
    fmt=lambda x: f'{x*1e-6:.1f}M',
    padding=-15,
    color='lightcyan',
    weight='demi')
ventas.locator_params(axis='y', nbins=15)

# Etiquetas en X horizontales
plt.xticks(rotation=0)

# Referncia ala gráfica
plt.figtext(0.5, 0.01, 'Figura 1. Facturación total de las tiendas',
            ha='center', fontsize=10, color='gray')

# Mostrar gráfico
plt.show()

# %%
porcentaje_comparacion = resultados['Facturación']

base = porcentaje_comparacion.min()
pct = (porcentaje_comparacion / base - 1) * 100

fig, ax = plt.subplots(figsize=(8,6))

ax.plot(
    porcentaje_comparacion.index,
    pct,
    color='coral',
    marker='o',
    linewidth=2
)

# Números en los puntos
for x, y in zip(porcentaje_comparacion.index, pct):
    ax.text(x, y + 0.5, f'{y:.1f}%', ha='center', va='bottom', color='indianred', fontsize=10)

# Limite mayor para que quepan los números
ax.set_ylim(0, 13)
ax.set_ylabel('Porcentaje sobre Tienda 4')
ax.grid(axis='y', linestyle=':', alpha=0.6)
plt.xticks(rotation=0)

fig.text(0.5, 0.01, 'Figura 2. Diferencia relativa de facturación vs. Tienda 4',
         ha='center', va='bottom', fontsize=10, color='gray')

plt.show()

# %% [markdown]
# ## Comparativa de costos de envío

# %%
costos_envio = resultados['Costo de envío'].plot(kind='bar', ylabel='Costos de envío promedio en pesos colombianos' , figsize=(8,6), legend=False,  color='mediumseagreen')
plt.grid(axis='y', linestyle='--', alpha=1, color='green')

plt.xticks(rotation=0)

plt.figtext(0.5, 0.01, 'Figura 3. Costos de envío promedio por tienda',
            ha='center', fontsize=10, color='gray')

plt.show()

# %% [markdown]
# ## Comparativa de categorías de productos vendidos

# %%
# Para poner los rectángulos de color en categrías en la leyenda
from matplotlib.patches import Patch

# Lista de cada Serie guardando las sumas de categorías
series_por_tienda = resultados["Categorías de Productos"]
categorias = list(series_por_tienda.iloc[0].index)

# Paleta de colores sueaves pero bien diferenciados
palette_soft_harmony = [
    "#E57373",  # soft brick red
    "#F4A261",  # muted orange, earthy and warm (like terracotta)
    "skyblue",  # clear sky blue
    "#A8E36B",
    "#BA68C8",  # soft purple
    "lightseagreen",  # teal
    "#F4D35E",  # mellow yellow (natural, not bright neon)
    "#A1887F"   # taupe brown / neutral
]

# Para asegurar consistencia en uso de colores en las categorías
color_map = {cat: palette_soft_harmony[i] for i, cat in enumerate(categorias)}

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Aplanar arreglo 2D de los gráficos en una lista para iterar con un solo ciclo
axs = axs.flatten()

for i, tienda in enumerate(series_por_tienda.index):
    s = series_por_tienda[tienda].sort_values()

    # Generación de cada gráfico de pastel
    axs[i].pie(
        s.values,
        labels=None,
        autopct='%1.1f%%',
        startangle=90,
        colors=[color_map[c] for c in s.index]
    )

    axs[i].set_title(tienda)
    axs[i].axis('equal')

# Leyenda al centro para no repetir etiquetas en cada gráfico
categorias = series_por_tienda.iloc[0].index
handles = [Patch(facecolor=color_map[c], edgecolor='none') for c in categorias]
fig.legend(
    handles,
    categorias,
    loc='center',
    ncol=1,
    bbox_to_anchor=(0.50, 0.49)
)

plt.tight_layout()

plt.figtext(0.5, 0.01, 'Figura 4. Proporción de ventas por categoría por tienda',
            ha='center', fontsize=10, color='gray')

plt.show()

# %% [markdown]
# ## Comparativa de calificaciones de clientes

# %%
calificaciones = resultados['Calificación'].plot(kind='barh',
                                                 xlabel='Calificación promedio',
                                                 figsize=(6, 6),
                                                 legend=False,
                                                 color='goldenrod')
plt.grid(axis='x', linestyle=':', alpha=0.8)
calificaciones.set_xlim(0, 5) # Límite al máximo posible (5/5 estrellas)
plt.yticks(rotation=90 )
calificaciones.bar_label(calificaciones.containers[0],
                         fmt='%.2f',
                         padding=10,
                         color='darkgoldenrod',
                         weight='demi')
for label in calificaciones.get_yticklabels():
    label.set_va('center')

plt.figtext(0.5, -0.01, 'Figura 5. Calificación de los clientes para cada tienda',
            ha='center', fontsize=10, color='gray')

plt.show()

# %% [markdown]
# # Informe Final

# %% [markdown]
# Se realizó un análisis de las métricas en las cuatro tiendas para encontrar cuál de ellas sería más conveniente vender. Se analizaron tanto las variables de ventas y satisfacción de clientes así como aquellas que impactan estrategias de ventas.
#
# Se descubrió que la **tienda número 4** muestra una clara desventaja respecto a las demás por su menor rentabilidad a pesar de contar con ventajas estratégicas respecto a las demás:
#
# Primero, su **facturación** total es significativemente menor a la de las otras tiendas, siendo solamente de 1 308.4 millones de pesos colombianos (COP), contra 1 150.9, 1 116.3, y 1 098.0 millones COP de las otras tres (fig. 1), representando una diferencia que va del 6% al 11% (fig. 2).
#
# En segundo lugar, se encontró que la tienda número 4 cuenta con una ventaja en sus **costos de envío** respecto a las demás (fig 3), siendo estos significativamente más bajos en promedio, lo cual no se ha reflejado en mayores ventas como se podría esperar.
#
# Al analizar las categorías de productos vendidos, se encontraron diferencias en las tiendas 3 y 4, respecto a las otras dos. En la número tres, las ventas de **libros** son mayores a las de **instrumentos musicales**, y en la número cuatro, las ventas de **artículos para el hogar** son mayores a las de las dos categorías anteriomente mencionadas, lo cual difiere con las otras tres tiendas. Más significativamente, las ventas en la categoría de **deportes y diversión** en la tienda 4 superan a las de **electrodomésticos**, a diferencia de las otras tres tiendas también (fig. 4). Esto significa que cualquier estrategia de marketing como descuentos en productos o campañas promocionales tendrán que tomar en cuenta las diferencias de la tienda 4, lo cual puede complicar su implementación y reducir su efectividad.
#
# Por último, en cuanto a la calificación que los clientes dan a las tiendas, no se encontró una diferencia significativa en ninguna de ellas, ya que todas se encuentran entre el 3.98 y el 4.05 (fig. 5), por lo que esto no afectó la decisión en un sentido u otro.
#
# En conclusión, se recomienda la venta de la tienda número 4 debido a su menor rentabilidad y desventaja competitiva.
